# %%
print("hello i am leila i co mmitedin")
# Out:
# hello i am leila i co mmitedin

# %%
import getpass, os

USERNAME = "LeilaAyman"        # your GitHub username
OWNER = "LeilaAyman"           # repo owner (same as username)
REPO = "visualization-repo"    # ONLY the repo name

# Ask for your token safely
token = getpass.getpass("Enter your GitHub token: ")

# Build authenticated URL
repo_url = f"https://{USERNAME}:{token}@github.com/{OWNER}/{REPO}.git"

# Export for shell
os.environ["REPO_URL"] = repo_url
os.environ["REPO_NAME"] = REPO

print("Repo URL is ready.")
# Out:
# Enter your GitHub token: ··········
# Repo URL is ready.

# %%
# Remove old clone (if any)
# !rm -rf $REPO_NAME

# Clone using token
# !git clone "$REPO_URL"

# IMPORTANT: cd without quotes, without $ inside a string
# %cd visualization-repo
# Out:
# Cloning into 'visualization-repo'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/visualization-repo

# %%
# !git config user.name "Leila Ayman"
# !git config user.email "mariamaymanaliomar@gmail.com"

# %%
print('hiii again' )
print('hiii again' )
# Out:
# hiii again
# hiii again

# %%
# !git add .

# %%
# !git commit -m "moot"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# %cd /content/visualization-repo
# !git add untitled33.ipynb
# !git commit -m "Updated notebook"
# !git push
# Out:
# /content/visualization-repo
# fatal: pathspec 'untitled33.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
